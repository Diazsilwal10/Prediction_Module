# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks

# %%
df=pd.DataFrame(pd.read_csv("insurance.csv"))
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
row,col=df.shape
print("no of rows =",row)
print("no of rows =",col)
# Out:
# no of rows = 1338
# no of rows = 7

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
print(len(set(df["age"])))
print(len(set(df["smoker"])))
print(len(set(df["expenses"])))
# Out:
# 47
# 2
# 1337

# %%
auto=df[["age",'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']]

# %%
sns.pairplot(auto)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
auto1=df[['age',"children","expenses"]]
auto1.corr()
# Out:
#                age  children  expenses
# age       1.000000  0.042469  0.299008
# children  0.042469  1.000000  0.067998
# expenses  0.299008  0.067998  1.000000

# %%
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(auto1.corr(),annot=True)
plt.show()

# %%
auto
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
Sex = pd.get_dummies(auto['sex'],drop_first=True)
Sex
# Out:
#        male
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# ...     ...
# 1333   True
# 1334  False
# 1335  False
# 1336  False
# 1337  False
#
# [1338 rows x 1 columns]

# %%
auto =pd.concat([auto,Sex],axis=1)
auto
# Out:
#       age     sex   bmi  children smoker     region  expenses   male
# 0      19  female  27.9         0    yes  southwest  16884.92  False
# 1      18    male  33.8         1     no  southeast   1725.55   True
# 2      28    male  33.0         3     no  southeast   4449.46   True
# 3      33    male  22.7         0     no  northwest  21984.47   True
# 4      32    male  28.9         0     no  northwest   3866.86   True
# ...   ...     ...   ...       ...    ...        ...       ...    ...
# 1333   50    male  31.0         3     no  northwest  10600.55   True
# 1334   18  female  31.9         0     no  northeast   2205.98  False
# 1335   18  female  36.9         0     no  southeast   1629.83  False
# 1336   21  female  25.8         0     no  southwest   2007.95  False
# 1337   61  female  29.1         0    yes  northwest  29141.36  False
#
# [1338 rows x 8 columns]

# %%
smoke = pd.get_dummies(auto["smoker"],drop_first=False)
smoke
# Out:
#          no    yes
# 0     False   True
# 1      True  False
# 2      True  False
# 3      True  False
# 4      True  False
# ...     ...    ...
# 1333   True  False
# 1334   True  False
# 1335   True  False
# 1336   True  False
# 1337  False   True
#
# [1338 rows x 2 columns]

# %%
auto = pd.concat([auto,smoke],axis=1)
auto
# Out:
#       age     sex   bmi  children smoker     region  expenses   male     no  \
# 0      19  female  27.9         0    yes  southwest  16884.92  False  False
# 1      18    male  33.8         1     no  southeast   1725.55   True   True
# 2      28    male  33.0         3     no  southeast   4449.46   True   True
# 3      33    male  22.7         0     no  northwest  21984.47   True   True
# 4      32    male  28.9         0     no  northwest   3866.86   True   True
# ...   ...     ...   ...       ...    ...        ...       ...    ...    ...
# 1333   50    male  31.0         3     no  northwest  10600.55   True   True
# 1334   18  female  31.9         0     no  northeast   2205.98  False   True
# 1335   18  female  36.9         0     no  southeast   1629.83  False   True
# 1336   21  female  25.8         0     no  southwest   2007.95  False   True
# 1337   61  female  29.1         0    yes  northwest  29141.36  False  False
#
#         yes
# 0      True
# 1     False
# 2     False
# ...

# %%
auto = auto.drop(['region','smoker'],axis=1)
auto
# Out:
#       age     sex   bmi  children  expenses   male     no    yes
# 0      19  female  27.9         0  16884.92  False  False   True
# 1      18    male  33.8         1   1725.55   True   True  False
# 2      28    male  33.0         3   4449.46   True   True  False
# 3      33    male  22.7         0  21984.47   True   True  False
# 4      32    male  28.9         0   3866.86   True   True  False
# ...   ...     ...   ...       ...       ...    ...    ...    ...
# 1333   50    male  31.0         3  10600.55   True   True  False
# 1334   18  female  31.9         0   2205.98  False   True  False
# 1335   18  female  36.9         0   1629.83  False   True  False
# 1336   21  female  25.8         0   2007.95  False   True  False
# 1337   61  female  29.1         0  29141.36  False  False   True
#
# [1338 rows x 8 columns]

# %%
auto = auto.drop(['sex'],axis=1)
auto
# Out:
#       age   bmi  children  expenses   male     no    yes
# 0      19  27.9         0  16884.92  False  False   True
# 1      18  33.8         1   1725.55   True   True  False
# 2      28  33.0         3   4449.46   True   True  False
# 3      33  22.7         0  21984.47   True   True  False
# 4      32  28.9         0   3866.86   True   True  False
# ...   ...   ...       ...       ...    ...    ...    ...
# 1333   50  31.0         3  10600.55   True   True  False
# 1334   18  31.9         0   2205.98  False   True  False
# 1335   18  36.9         0   1629.83  False   True  False
# 1336   21  25.8         0   2007.95  False   True  False
# 1337   61  29.1         0  29141.36  False  False   True
#
# [1338 rows x 7 columns]

# %%
auto.corr()
# Out:
#                age       bmi  children  expenses      male        no       yes
# age       1.000000  0.109341  0.042469  0.299008 -0.020856  0.025019 -0.025019
# bmi       0.109341  1.000000  0.012645  0.198576  0.046380 -0.003968  0.003968
# children  0.042469  0.012645  1.000000  0.067998  0.017163 -0.007673  0.007673
# expenses  0.299008  0.198576  0.067998  1.000000  0.057292 -0.787251  0.787251
# male     -0.020856  0.046380  0.017163  0.057292  1.000000 -0.076185  0.076185
# no        0.025019 -0.003968 -0.007673 -0.787251 -0.076185  1.000000 -1.000000
# yes      -0.025019  0.003968  0.007673  0.787251  0.076185 -1.000000  1.000000

# %%
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(auto.corr(),annot=True)
plt.show()

# %%
auto
# Out:
#       age   bmi  children  expenses   male     no    yes
# 0      19  27.9         0  16884.92  False  False   True
# 1      18  33.8         1   1725.55   True   True  False
# 2      28  33.0         3   4449.46   True   True  False
# 3      33  22.7         0  21984.47   True   True  False
# 4      32  28.9         0   3866.86   True   True  False
# ...   ...   ...       ...       ...    ...    ...    ...
# 1333   50  31.0         3  10600.55   True   True  False
# 1334   18  31.9         0   2205.98  False   True  False
# 1335   18  36.9         0   1629.83  False   True  False
# 1336   21  25.8         0   2007.95  False   True  False
# 1337   61  29.1         0  29141.36  False  False   True
#
# [1338 rows x 7 columns]

# %%
auto=auto.drop(['bmi'],axis =1)
auto
# Out:
#       age  children  expenses   male     no    yes
# 0      19         0  16884.92  False  False   True
# 1      18         1   1725.55   True   True  False
# 2      28         3   4449.46   True   True  False
# 3      33         0  21984.47   True   True  False
# 4      32         0   3866.86   True   True  False
# ...   ...       ...       ...    ...    ...    ...
# 1333   50         3  10600.55   True   True  False
# 1334   18         0   2205.98  False   True  False
# 1335   18         0   1629.83  False   True  False
# 1336   21         0   2007.95  False   True  False
# 1337   61         0  29141.36  False  False   True
#
# [1338 rows x 6 columns]

# %%
auto['expenses']=auto['expenses'].astype('int')

# %%
from sklearn.model_selection import train_test_split
# We specify this so that the train and test data set always have the same rows, respectively
df_train, df_test = train_test_split(auto, train_size = 0.85, test_size = 0.15, random_state = 1)

# %%
df_train.shape
# Out:
# (1137, 6)

# %%
df_test.shape
# Out:
# (201, 6)

# %%
from sklearn.linear_model import LinearRegression
X_train = df_train[['age',"children",'male','no','yes']]

y_train = df_train['expenses'].astype("int")
df_test_predict = X_train.iloc[0:1]
# for linear regression
lm = LinearRegression()
lr_model = lm.fit(X_train, y_train)

#for logistic regression
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()
lg_model = lg.fit(X_train, y_train)

#for polynomial regression
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=7)
# poly_reg.fit(X, y)
X_poly = poly_reg.fit_transform(X_train)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y_train)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LinearRegression()

# %%
print("Linear regression =",lr_model.score(X_train,y_train))
print("Logistic regression=",lg_model.score(X_train,y_train))
print("polynomial regression=",pol_reg.score(poly_reg.fit_transform(X_train),y_train))
# Out:
# Linear regression = 0.7260801555682304
# Logistic regression= 0.03518029903254178
# polynomial regression= 0.7652564013631219

# %%
data = df_test.iloc[30:31].astype("int")
actual_expenses = data['expenses']
data = data.drop(['expenses'],axis = 1)
data
# Out:
#      age  children  male  no  yes
# 945   56         1     0   1    0

# %%
X_train
# Out:
#       age  children   male     no    yes
# 215    41         2  False   True  False
# 1035   54         3  False   True  False
# 1211   39         2   True   True  False
# 1173   38         2   True   True  False
# 236    18         0  False   True  False
# ...   ...       ...    ...    ...    ...
# 715    60         0   True   True  False
# 905    26         2  False   True  False
# 1096   51         2  False  False   True
# 235    40         2  False  False   True
# 1061   57         1   True   True  False
#
# [1137 rows x 5 columns]

# %%
predicted_expenses_lr=lr_model.predict(data)
predicted_expenses_lg=lg_model.predict(data)
data_poly=poly_reg.transform(data)
predicted_expenses_pol=pol_reg.predict(data_poly)
print("predicted expenses using linear regression:",predicted_expenses_lr)
print("predict expenses using logistic regression:",predicted_expenses_lg)
print("predicrt expenses using polynomial regression:",predicted_expenses_pol)

print("Actual expenses:",actual_expenses)
# Out:
# predicted expenses using linear regression: [13050.38029488]
# predict expenses using logistic regression: [11842]
# predicrt expenses using polynomial regression: [14302.45906855]
# Actual expenses: 945    11674
# Name: expenses, dtype: int64

# %%
age = int(input("enter age:"))
smoker=(input("enter smoke (1 for yes, 0 for no):"))
children=(input("children(1 for yes,0 for no):"))
male=(input("enter gender(1 for male, 0 for female):"))

data={'age':[age],
      'smoke':[smoker],
      'chldren':[children],
      'male':[male]}
df=pd.DataFrame(data)
predict_expenses_pol=pol_reg.predict(data_poly)
print("predicted expenses:",predicted_expenses_pol)
print(df)
# Out:
# enter age: 25
# enter smoke (1 for yes, 0 for no): 1
# children(1 for yes,0 for no): 0
# enter gender(1 for male, 0 for female): 1
# predicted expenses: [14302.45906855]
#    age smoke chldren male
# 0   25     1       0    1

# %%
df.describe()
# Out:
#         age
# count   1.0
# mean   25.0
# std     NaN
# min    25.0
# 25%    25.0
# 50%    25.0
# 75%    25.0
# max    25.0

# %%
plt.scatter(y_train,lr_model.predict(X_train),color = 'red')
plt.xlabel('Actual expenses')
plt.ylabel('Predicted expenses')
plt.show()

# %%
plt.scatter(y_train,lg_model.predict(X_train),color = 'red')
plt.xlabel('Actual expenses')
plt.ylabel('Predicted expenses')
plt.show()

# %%
plt.scatter(y_train,pol_reg.predict(poly_reg.fit_transform(X_train)),color = 'red')
plt.xlabel('Actual expenses')
plt.ylabel('Predicted expenses')
plt.show()

# %%
x = [i for i in range(15)]
plt.scatter(x,x,color='red')
